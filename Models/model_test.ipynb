# %%
import tensorflow as tf
import os
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/256_Resnet152_new')

# %%
os.chdir('/content/drive/MyDrive/hi')
files = os.listdir()

# %%
import cv2
pic = cv2.imread("/content/drive/MyDrive/hi/1_.jpeg")
pic = cv2.resize(pic, (256, 256))
#pic = cv2.flip(pic, 1)
from google.colab.patches import cv2_imshow
cv2_imshow(pic)
pic = pic/255.
#print(pic)

import numpy as np
pic = np.reshape(pic, (1, 256, 256, -1))
opt = model.predict(pic)

print(opt)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FAF42E6FF10>
# [[9.68825996e-01 4.06047917e-07 6.39033715e-06 3.13799319e-06
#   1.78743744e-06 6.80947909e-04 2.12189184e-06 1.44016346e-08
#   4.61715899e-06 1.28795875e-06 2.74230871e-07 7.09057588e-07
#   2.13400071e-08 3.13462664e-07 8.17491673e-06 2.43011182e-05
#   7.91795500e-08 5.56799205e-06 1.33535953e-03 1.52018129e-05
#   7.19818490e-05 2.16325661e-05 5.64234142e-06 3.13408731e-04
#   4.68223607e-06 3.84686398e-04 2.75332313e-02 1.63038148e-05
#   8.70383519e-05 4.81037823e-05 2.99715089e-06 3.51215385e-06
#   4.19932912e-05 5.04227646e-05 4.81643519e-06 2.74172955e-04
#   2.14278316e-07 3.59723936e-06 2.69148336e-06 5.10558275e-05
#   6.65069092e-05 9.44596832e-05]]

# %%
os.chdir('/content/drive/MyDrive/hi')
files = os.listdir()

# %%
import numpy as np
import tensorflow as tf
import cv2
import glob
import random
from PIL import Image
from google.colab.patches import cv2_imshow
from skimage.transform import resize
images = []
y = []
#images = np.array(images)
h = 0
cnt = 0
for i in files:
    #print(y)
    pic = cv2.imread(i)
    #pic = cv.cvtColor(pic, cv.COLOR_BGR2GRAY)
    #print(pic.shape)
    pic = cv2.resize(pic, (256, 256))
    #cv2_imshow(pic)
    key = cv2.waitKey(0)
    images.append(pic)
x = np.array(images)
x = x.astype('float32')
x /= 255 
t = model.predict(x)

x = 0
for i in files:
    #print(i)
    pic = cv2.imread(i)
    pic = cv2.resize(pic, (256, 256))
    cv2_imshow(pic)
    print(t[x].argmax()+1)
    x += 1
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-0d61455a5117> in <module>()
#      17     #pic = cv.cvtColor(pic, cv.COLOR_BGR2GRAY)
#      18     #print(pic.shape)
# ---> 19     pic = cv2.resize(pic, (256, 256))
#      20     #cv2_imshow(pic)
#      21     key = cv2.waitKey(0)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
